# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ML-Village/rl-games/blob/main/pacmanghosts/notebooks/ms_pacman.ipynb)

# %%
# @title Setup gym and the stable baseline environment
# !pip install gym
# !pip install "gym[atari, accept-rom-license]"
#!pip install 'gym[box2d]'
# !pip install atari_py
# !apt install cmake libopenmpi-dev zlib1g-dev
# !pip install stable-baselines==2.3.0
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !pip install tensorflow
# !pip install torch

# %%
# @title Set-up the virtual display environment
# !apt-get update
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !apt-get install ffmpeg -y

# %%
# @title Import all we need
import gym
from gym import wrappers
from gym.wrappers.monitoring import video_recorder
# OS
import os
#import numpy
import numpy as np
#Google colab tools
from google.colab import files # To handle files and eg export to your browser
import glob # To handle files and eg export to your browser
from google.colab import drive # Mount your Google drive

# #Stable baselines
# from stable_baselines import PPO2, ACER
# from stable_baselines.common.atari_wrappers import wrap_deepmind, NoopResetEnv, MaxAndSkipEnv
# from stable_baselines.common.policies import MlpPolicy, CnnPolicy, MlpLnLstmPolicy, CnnLnLstmPolicy
# from stable_baselines.common.vec_env import VecEnvWrapper, DummyVecEnv, VecNormalize, VecFrameStack, SubprocVecEnv
# from stable_baselines.common.cmd_util import make_atari_env
# from stable_baselines import logger
# from stable_baselines.bench import Monitor
# from stable_baselines.results_plotter import load_results, ts2xy

# matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# @title Start the virtual monitor
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# @title Select game
# which arcade environment?
env_id = 'ALE/MsPacman-v5'  # @param
# file directory
monitor_dir = '/content/drive/My Drive/pacmanPPO'  # @param

# %%
# @title Show a game screen and action spaces
env = gym.make(env_id, render_mode="rgb_array")
state = env.reset()
frame = env.render("rgb_array")
plt.imshow(frame)
#plt.grid(False)
print("Action space:", env.action_space)
print("Observation space:", env.observation_space)
# Out:
# Action space: Discrete(9)
# Observation space: Box(0, 255, (210, 160, 3), uint8)

# %%
print(state.shape)
# Print dimensions of state and action space
print("State space: {}".format(env.observation_space))
print("Action space: {}".format(env.action_space))
# Out:
# (210, 160, 3)
# State space: Box(0, 255, (210, 160, 3), uint8)
# Action space: Discrete(9)
